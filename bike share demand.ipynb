# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"/Users/gunhoro/Desktop/projects/Bike/day.csv")

# %% [markdown]
# # 1. Plot data vs count, registered, casual (Compare by seasons/ month every year)
# # 2. Compare working day and holiday
# # 3. Correlation analysis : temperature humidity, atemp, windspeed, weather etc.
# # 4. Plot hourly vs demand (Find highest demand time and see how that time varies over different months)
# # 5. Polynomial Regression
# # 6. Random Forest Regressor

# %%
df["dteday"]= pd.to_datetime(df["dteday"]) 
plt.xticks(rotation=90)
plt.plot_date(df.dteday, df.cnt)
# Out:
# /Users/gunhoro/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
by_year = pd.pivot_table(df, index=df.dteday.dt.month, columns=df.dteday.dt.year,
                    values='cnt', aggfunc='sum')
by_year.plot()

# %%
plt.xticks(rotation=90)
plt.plot_date(df.dteday, df.casual)
plt.plot_date(df.dteday, df.registered)
plt.plot_date(df.dteday, df.cnt)
plt.legend(["Casual", "Registered","Total"])

# %%
df.groupby(by=["workingday"]).mean()
# Out:
#               instant   season        yr      mnth   holiday   weekday  \
# workingday
# 0           367.34632  2.47619  0.502165  6.549784  0.090909  2.891775
# 1           365.37800  2.50600  0.500000  6.506000  0.000000  3.046000
#
#             weathersit      temp     atemp       hum  windspeed       casual  \
# workingday
# 0              1.34632  0.481213  0.461852  0.622800   0.192628  1371.134199
# 1              1.41800  0.501932  0.480130  0.630248   0.189497   606.570000
#
#              registered          cnt
# workingday
# 0           2959.034632  4330.168831
# 1           3978.250000  4584.820000

# %%
df
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 2          3 2011-01-03       1   0     1        0        1           1
# 3          4 2011-01-04       1   0     1        0        2           1
# 4          5 2011-01-05       1   0     1        0        3           1
# 5          6 2011-01-06       1   0     1        0        4           1
# 6          7 2011-01-07       1   0     1        0        5           1
# 7          8 2011-01-08       1   0     1        0        6           0
# 8          9 2011-01-09       1   0     1        0        0           0
# 9         10 2011-01-10       1   0     1        0        1           1
# 10        11 2011-01-11       1   0     1        0        2           1
# 11        12 2011-01-12       1   0     1        0        3           1
# ...

# %%
df[['temp','hum','windspeed','holiday','season','cnt']].corr()
# Out:
#                temp       hum  windspeed   holiday    season       cnt
# temp       1.000000  0.126963  -0.157944 -0.028556  0.334315  0.627494
# hum        0.126963  1.000000  -0.248489 -0.015937  0.205445 -0.100659
# windspeed -0.157944 -0.248489   1.000000  0.006292 -0.229046 -0.234545
# holiday   -0.028556 -0.015937   0.006292  1.000000 -0.010537 -0.068348
# season     0.334315  0.205445  -0.229046 -0.010537  1.000000  0.406100
# cnt        0.627494 -0.100659  -0.234545 -0.068348  0.406100  1.000000

# %%
sns.heatmap(df[['temp','hum','windspeed','holiday','season','cnt']].corr(),vmax=0.7, center=0,square=True, linewidths=0.5)

# %%
df_hourly=pd.read_csv(r"/Users/gunhoro/Desktop/projects/Bike/hour.csv")

# %%
for i in range(1,5):
    by_season_hour=df_hourly[df_hourly.season==i]
    year_hour_group=by_season_hour.groupby('hr')['cnt'].agg('sum')
    plt.rcParams["figure.figsize"]=(20,5)

    plt.plot(year_hour_group)

# %%
from sklearn.linear_model import LinearRegression
year_hourly_sum=year_hour_group.reset_index()
x=year_hourly_sum[['hr']]
y=year_hourly_sum[['cnt']]
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)
plt.scatter(x, y, s=10)
plt.plot(x, y_pred, color='r')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
for i in range(2,10):
    polynomial_features= PolynomialFeatures(degree=i)
    x_poly = polynomial_features.fit_transform(x)

    model = LinearRegression()
    model.fit(x_poly, y)
    y_poly_pred = model.predict(x_poly)
    plt.scatter(x, y, s=10)
    plt.plot(x, y_poly_pred, color='m')
    plt.legend([i])
    r2 = r2_score(y,y_poly_pred)
    print(r2)
# Out:
# 0.6021007824413656
# 0.7353874634220311
# 0.7355968272150492
# 0.7481051670306949
# 0.7909873954393489
# 0.8540014947924465
# 0.8784574019004906
# 0.8954609154509088

# %%
x=df.iloc[:,9:10].values
y=df.iloc[:,15].values
from sklearn.ensemble import RandomForestRegressor 
  
 # create regressor object 
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0) 
  
# fit the regressor with x and y data 
regressor.fit(x, y)  
Y_pred = regressor.predict(np.array([6.5]).reshape(1,1))  # test the output by changing values

# %%
X_grid = np.arange(min(x), max(x), 0.01)  
  
# reshape for reshaping the data into a len(X_grid)*1 array,  
# i.e. to make a column out of the X_grid value                   
X_grid = X_grid.reshape((len(X_grid), 1)) 
  
# Scatter plot for original data 
plt.scatter(x, y, color = 'blue')   
  
# plot predicted data 
plt.plot(X_grid, regressor.predict(X_grid),  
         color = 'green')  
plt.title('Random Forest Regression') 
plt.xlabel('temperature') 
plt.ylabel('Bike Demand') 
plt.show()
